# %% [markdown]
# ## Testing Random Forest Regressor

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Data

# %%
X_train = pd.read_csv("flatdata.csv")

# %%
X_train.head(10)
# Out:
#    Unnamed: 0     cloud  latitude  longitude       scl  ev_index  \
# 0           0 -0.184414  6.873240  -3.528786 -0.319139  0.114938
# 1           1 -0.184414  7.688378  -2.940739 -0.333007  0.115578
# 2           2 -0.184414  6.949442  -5.455622 -0.333007  0.103462
# 3           3 -0.184414  6.949802  -5.455349 -0.333007  0.102807
# 4           4 -0.184414  6.950253  -5.455077 -0.333007  0.102917
# 5           5 -0.184414  6.950702  -5.454713 -0.333007  0.110886
# 6           6 -0.184414  6.951062  -5.454441 -0.333007  0.111839
# 7           7 -0.184414  6.951512  -5.454168 -0.333007  0.116199
# 8           8 -0.184414  6.951872  -5.453805 -0.333007  0.118089
# 9           9 -0.184414  6.952322  -5.453532 -0.333007  0.118569
#
#    Coastal_Aerosol_1    Blue_2   Green_3     Red_4  Vegetation_Red_Edge_5  \
# 0          -0.582740 -0.507224 -0.372343 -0.421745              -0.226636
# 1          -0.802716 -0.708350 -0.726663 -0.675212              -0.769121
# ...

# %%
X_train = X_train.drop(columns="Unnamed: 0")

# %%
X_train.head(10)
# Out:
#       cloud  latitude  longitude       scl  ev_index  Coastal_Aerosol_1  \
# 0 -0.184414  6.873240  -3.528786 -0.319139  0.114938          -0.582740
# 1 -0.184414  7.688378  -2.940739 -0.333007  0.115578          -0.802716
# 2 -0.184414  6.949442  -5.455622 -0.333007  0.103462          -0.556770
# 3 -0.184414  6.949802  -5.455349 -0.333007  0.102807          -0.547417
# 4 -0.184414  6.950253  -5.455077 -0.333007  0.102917          -0.546320
# 5 -0.184414  6.950702  -5.454713 -0.333007  0.110886          -0.552528
# 6 -0.184414  6.951062  -5.454441 -0.333007  0.111839          -0.563289
# 7 -0.184414  6.951512  -5.454168 -0.333007  0.116199          -0.585531
# 8 -0.184414  6.951872  -5.453805 -0.333007  0.118089          -0.599614
# 9 -0.184414  6.952322  -5.453532 -0.333007  0.118569          -0.603814
#
#      Blue_2   Green_3     Red_4  Vegetation_Red_Edge_5  \
# 0 -0.507224 -0.372343 -0.421745              -0.226636
# 1 -0.708350 -0.726663 -0.675212              -0.769121
# ...

# %%
y_train = pd.read_csv("targets.csv")

# %%
y_train.head()
# Out:
#    Unnamed: 0       agbd
# 0           0  10.646117
# 1           1  99.101875
# 2           2  30.911081
# 3           3  14.941122
# 4           4  18.502295

# %%
y_train = y_train.drop(columns="Unnamed: 0")

# %%
y_train.head()
# Out:
#         agbd
# 0  10.646117
# 1  99.101875
# 2  30.911081
# 3  14.941122
# 4  18.502295

# %% [markdown]
# # Train, Val split

# %%
X_train_np = X_train.to_numpy()
y_train_np = y_train.to_numpy().ravel()

# %%
from sklearn.model_selection import train_test_split

X_train_main,X_val, y_train_main,  y_val = train_test_split(X_train_np, y_train_np, test_size=0.2, random_state=42)

# %%
X_train_main.shape
# Out:
# (20028, 17)

# %%
y_train_main.shape
# Out:
# (20028,)

# %% [markdown]
# ## Model

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

rf_model.fit(X_train_main, y_train_main)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ## Evaluate

# %%
from sklearn.metrics import mean_squared_error

y_pred = rf_model.predict(X_val)
mse = mean_squared_error(y_val, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {np.sqrt(mse)}")
# Out:
# Mean Squared Error: 2900.498000102841
# Root Mean Squared Error: 53.85627168773235
